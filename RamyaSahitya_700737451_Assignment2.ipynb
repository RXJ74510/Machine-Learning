# %% [markdown]
# <a href="https://colab.research.google.com/github/RXJ74510/Machine-Learning/blob/main/RamyaSahitya_700737451_Assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Q1

import numpy as np

# %%
arr = np.random.randint(1, 20, size=[1, 15])
arr.shape = (3, 5)
print("Array shape: " + str(arr.shape))
# print(arr)
max_val = np.max(arr)

arr[arr == max_val] = 0
# Out:
# Array shape: (3, 5)

# %%
#Q2

# %%
import pandas as pd

url = 'https://drive.google.com/file/d/1-Ir3AXK1A77A-qCDu5gGkAxv-nbmWlHO/view?usp=sharing'
url='https://drive.google.com/uc?id=' + url.split('/')[-2]
df1 = pd.read_csv(url)
print(df1.describe())

df1.replace(np.nan, df1.mean())
# Out:
#          Duration       Pulse    Maxpulse     Calories
# count  169.000000  169.000000  169.000000   164.000000
# mean    63.846154  107.461538  134.047337   375.790244
# std     42.299949   14.510259   16.450434   266.379919
# min     15.000000   80.000000  100.000000    50.300000
# 25%     45.000000  100.000000  124.000000   250.925000
# 50%     60.000000  105.000000  131.000000   318.600000
# 75%     60.000000  111.000000  141.000000   387.600000
# max    300.000000  159.000000  184.000000  1860.400000
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# ...

# %%
# df1.groupby(['Duration', 'Pulse']).agg(
#     min=pd.NamedAgg(column=['Duration', 'Pulse'], aggfunc=min),
#     max=pd.NamedAgg(column=['Duration', 'Pulse'], aggfunc=max),
#     count=pd.NamedAgg(column=['Duration', 'Pulse'], aggfunc=np.count_nonzero),
#     mean=pd.NamedAgg(column=['Duration', 'Pulse'], aggfunc=mean)
# )

# %%
df1_filtered = df1.query('Calories > 500 & Pulse < 100')
df1_filtered
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 65        180     90       130     800.4
# 70        150     97       129    1115.0
# 73        150     97       127     953.2
# 75         90     98       125     563.2
# 99         90     93       124     604.1
# 103        90     90       100     500.4
# 106       180     90       120     800.3
# 108        90     90       120     500.3

# %%
df_modified = df1[['Duration', 'Pulse', 'Calories']].copy()
df1 = df1.drop(columns=['Maxpulse'])

# %%
df1.replace(np.nan, 0).astype({'Calories': 'int32'})
# Out:
#      Duration  Pulse  Calories
# 0          60    110       409
# 1          60    117       479
# 2          60    103       340
# 3          45    109       282
# 4          45    117       406
# ..        ...    ...       ...
# 164        60    105       290
# 165        60    110       300
# 166        60    115       310
# 167        75    120       320
# 168        75    125       330
#
# [169 rows x 3 columns]

# %%
df1.plot.scatter(x='Duration',
                       y='Calories',
                       c='DarkBlue')

# %%
# Q3
import matplotlib.pyplot as plt
languages = 'Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++'
popuratity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
colors = ["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728", "#9467bd", "#8c564b"]
# explode 1st slice
explode = (0.1, 0, 0, 0,0,0)
# Plot
plt.pie(popuratity, explode=explode, labels=languages, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.show()
